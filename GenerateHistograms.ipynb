# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from plotnine import *
# %matplotlib inline
import calendar
from pandas.api.types import CategoricalDtype

#https://www.kaggle.com/datasets/theforcecoder/wind-power-forecasting?resource=download
df = pd.read_csv("Data/cleanData.csv", index_col=0)
df.drop(["month", "day", "year"], axis=1, inplace=True)

# %% [markdown]
# ### For each column in the cleaned data, plot the histogram and save to file to check for skewed data

# %%
plotList = []
for col in df.columns[1:]:
    hist = ggplot(df) + geom_histogram(aes(x = col), bins = 20, fill = "grey", color = "black")
    plotList.append(hist)
    ggsave(hist, filename="Plots/Histograms/" + col + ".png")
plotList
# Out:
# /usr/lib/python3.10/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /usr/lib/python3.10/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: Plots/Histograms/ActivePower.png
# /usr/lib/python3.10/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /usr/lib/python3.10/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: Plots/Histograms/AmbientTemperatue.png
# /usr/lib/python3.10/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /usr/lib/python3.10/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: Plots/Histograms/BearingShaftTemperature.png
# /usr/lib/python3.10/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /usr/lib/python3.10/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: Plots/Histograms/Blade1PitchAngle.png
# ...
